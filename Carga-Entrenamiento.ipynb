# %% [markdown]
# ## Importamos todas las librerias a usar

# %%
import numpy as np
import h5py
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay,confusion_matrix
import cv2
import warnings
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder 
import numpy as np

warnings.filterwarnings('ignore', category=UserWarning)

# %% [markdown]
# ## Cargamos los datos

# %%
def load_data(h5_filepath):
    with h5py.File(h5_filepath, 'r') as hf:
        X = hf['X'][:]
        Y = np.array([cadena.decode('utf-8')for cadena in hf['Y'][:]])
    return X, Y

X, y = load_data('./datos.h5')
print("Shape de X cargado:", X.shape)
print("Shape de Y cargado:", y.shape)
# Out:
# Shape de X cargado: (10000, 42)
# Shape de Y cargado: (10000,)

# %%
y
# Out:
# array(['1', '1', '1', ..., 'Y', 'Y', 'Y'], dtype='<U1')

# %%
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(y)

# %%
Y
# Out:
# array([ 0,  0,  0, ..., 24, 24, 24], dtype=int64)

# %% [markdown]
# ## Dividimos datos de entrenamiento y prueba

# %%
# Primera división: Dividir en conjunto de entrenamiento+validación y conjunto de prueba (90%-10%)
X_train_full, X_test, y_train_full, y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# Segunda división: Del 80% restante, dividir en entrenamiento y validación (90% entrenamiento, 10% validación)
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.11, random_state=42)

# %%
X_train.shape
# Out:
# (8010, 42)

# %%
X_val.shape
# Out:
# (990, 42)

# %%
X_test.shape
# Out:
# (1000, 42)

# %% [markdown]
# ## Entrenamiento

# %% [markdown]
# ### Curva de Precisión (Accuracy)
#
# - Muestra cómo evoluciona la precisión del modelo durante el proceso de entrenamiento y validación a lo largo de las épocas. Al principio (pocas epocas), el modelo tiene una precisión baja porque está empezando a aprender. A medida que las épocas aumentan, la precisión se eleva porque el modelo mejora.
# ### Curva de Pérdida (Loss)
# -  Muestra cómo cambia la pérdida del modelo durante el entrenamiento y validación a lo largo de las épocas. Al principio del entrenamiento, la pérdida es alta, ya que el modelo aún no ha aprendido. A medida que el entrenamiento avanza, la pérdida disminuye, lo cual indica que el modelo está aprendiendo a minimizar el error.

# %% [markdown]
# <img src="./img/curvas.jpeg" width="600px">

# %%
# Número de clases en tu problema
num_classes = len(np.unique(Y)) 

# Definir el modelo
model = Sequential()

# Capa de entrada
model.add(Dense(128, input_dim=X.shape[1], activation='relu'))  # 128 neuronas en la primera capa oculta

# Capas ocultas
model.add(Dense(64, activation='relu'))  # Capa oculta con 64 neuronas
model.add(Dense(32, activation='relu'))  # Capa oculta con 32 neuronas

# Capa de salida: usamos `softmax` para clasificación multiclase
model.add(Dense(num_classes, activation='softmax'))

# Compilar el modelo
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val))



# Graficar la precisión
plt.plot(history.history['accuracy'], label='Precisión en entrenamiento')
plt.plot(history.history['val_accuracy'], label='Precisión en validación')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.show()

# Graficar la pérdida
plt.plot(history.history['loss'], label='Pérdida en entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida en validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1209 - loss: 2.9776 - val_accuracy: 0.6061 - val_loss: 1.4534
# Epoch 2/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6913 - loss: 1.1670 - val_accuracy: 0.8242 - val_loss: 0.6481
# Epoch 3/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8641 - loss: 0.5421 - val_accuracy: 0.8707 - val_loss: 0.4110
# Epoch 4/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9096 - loss: 0.3510 - val_accuracy: 0.9525 - val_loss: 0.2622
# Epoch 5/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9433 - loss: 0.2438 - val_accuracy: 0.9677 - val_loss: 0.2050
# Epoch 6/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9460 - loss: 0.1994 - val_accuracy: 0.9576 - val_loss: 0.1911
# Epoch 7/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9587 - loss: 0.1574 - val_accuracy: 0.9697 - val_loss: 0.1433
# Epoch 8/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9627 - loss: 0.1348 - val_accuracy: 0.9657 - val_loss: 0.1436
# Epoch 9/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9708 - loss: 0.1164 - val_accuracy: 0.9556 - val_loss: 0.1570
# Epoch 10/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9771 - loss: 0.0959 - val_accuracy: 0.9657 - val_loss: 0.1197
# Epoch 11/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9744 - loss: 0.0895 - val_accuracy: 0.9747 - val_loss: 0.1026
# Epoch 12/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9749 - loss: 0.0840 - val_accuracy: 0.9869 - val_loss: 0.0815
# Epoch 13/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9866 - loss: 0.0581 - val_accuracy: 0.9899 - val_loss: 0.0732
# Epoch 14/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9831 - loss: 0.0695 - val_accuracy: 0.9869 - val_loss: 0.0717
# Epoch 15/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9842 - loss: 0.0578 - val_accuracy: 0.9919 - val_loss: 0.0626
# Epoch 16/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9898 - loss: 0.0421 - val_accuracy: 0.9879 - val_loss: 0.0662
# Epoch 17/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9954 - loss: 0.0303 - val_accuracy: 0.9929 - val_loss: 0.0515
# Epoch 18/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9829 - loss: 0.0508 - val_accuracy: 0.9939 - val_loss: 0.0547
# Epoch 19/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9913 - loss: 0.0338 - val_accuracy: 0.9889 - val_loss: 0.0543
# Epoch 20/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9958 - loss: 0.0236 - val_accuracy: 0.9889 - val_loss: 0.0560
# Epoch 21/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9782 - loss: 0.0585 - val_accuracy: 0.9919 - val_loss: 0.0470
# Epoch 22/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9916 - loss: 0.0279 - val_accuracy: 0.9960 - val_loss: 0.0424
# Epoch 23/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9955 - loss: 0.0214 - val_accuracy: 0.9899 - val_loss: 0.0514
# Epoch 24/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9904 - loss: 0.0354 - val_accuracy: 0.9980 - val_loss: 0.0359
# Epoch 25/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9970 - loss: 0.0152 - val_accuracy: 0.9919 - val_loss: 0.0493
# Epoch 26/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9967 - loss: 0.0160 - val_accuracy: 0.9939 - val_loss: 0.0545
# Epoch 27/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9940 - loss: 0.0247 - val_accuracy: 0.9970 - val_loss: 0.0346
# Epoch 28/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9898 - loss: 0.0335 - val_accuracy: 0.9899 - val_loss: 0.0479
# Epoch 29/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0164 - val_accuracy: 0.9899 - val_loss: 0.0536
# Epoch 30/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9909 - loss: 0.0269 - val_accuracy: 0.9919 - val_loss: 0.0476
# Epoch 31/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9977 - loss: 0.0132 - val_accuracy: 0.9970 - val_loss: 0.0375
# Epoch 32/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9992 - loss: 0.0072 - val_accuracy: 0.9970 - val_loss: 0.0350
# Epoch 33/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9876 - loss: 0.0366 - val_accuracy: 0.9929 - val_loss: 0.0476
# Epoch 34/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9952 - loss: 0.0147 - val_accuracy: 0.9980 - val_loss: 0.0378
# Epoch 35/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9988 - loss: 0.0071 - val_accuracy: 0.9485 - val_loss: 0.1478
# Epoch 36/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9899 - loss: 0.0299 - val_accuracy: 0.9949 - val_loss: 0.0399
# Epoch 37/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9767 - loss: 0.0765 - val_accuracy: 0.9949 - val_loss: 0.0374
# Epoch 38/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9995 - loss: 0.0055 - val_accuracy: 0.9970 - val_loss: 0.0336
# Epoch 39/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9983 - loss: 0.0067 - val_accuracy: 0.9970 - val_loss: 0.0352
# Epoch 40/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9991 - loss: 0.0054 - val_accuracy: 0.9939 - val_loss: 0.0510
# Epoch 41/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9967 - loss: 0.0097 - val_accuracy: 0.8697 - val_loss: 0.5179
# Epoch 42/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9741 - loss: 0.0660 - val_accuracy: 0.9970 - val_loss: 0.0347
# Epoch 43/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9998 - loss: 0.0045 - val_accuracy: 0.9919 - val_loss: 0.0432
# Epoch 44/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9947 - loss: 0.0211 - val_accuracy: 0.9980 - val_loss: 0.0243
# Epoch 45/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9989 - loss: 0.0053 - val_accuracy: 0.9980 - val_loss: 0.0256
# Epoch 46/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9983 - loss: 0.0066 - val_accuracy: 0.9879 - val_loss: 0.0493
# Epoch 47/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9675 - loss: 0.1120 - val_accuracy: 0.9970 - val_loss: 0.0336
# Epoch 48/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9995 - loss: 0.0038 - val_accuracy: 0.9980 - val_loss: 0.0319
# Epoch 49/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9999 - loss: 0.0022 - val_accuracy: 0.9970 - val_loss: 0.0317
# Epoch 50/50
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9989 - loss: 0.0032 - val_accuracy: 0.9980 - val_loss: 0.0325

# %%
# Evaluar el modelo en el conjunto de prueba
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Loss: {loss}, Accuracy: {accuracy}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.9989 - loss: 0.0058
# Loss: 0.007341523189097643, Accuracy: 0.9980000257492065

# %%
y_pred=[np.argmax(prediccion) for prediccion in model.predict(X_test)]
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
cf=confusion_matrix(y_test,y_pred)

# %%
cfd=ConfusionMatrixDisplay(cf,display_labels=label_encoder.classes_)
cfd.plot()

# %%
# Guardar el modelo completo
model.save('modelo.keras')
